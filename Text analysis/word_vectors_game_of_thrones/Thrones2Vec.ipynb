# %% [markdown]
# # Thrones2Vec

# %% [markdown]
# © Yuriy Guts, 2016

# %% [markdown]
# Using only the raw text of [A Song of Ice and Fire](https://en.wikipedia.org/wiki/A_Song_of_Ice_and_Fire), we'll derive and explore the semantic properties of its words.

# %% [markdown]
# ## Imports

# %%
from __future__ import absolute_import, division, print_function

# %%
import codecs
import glob
import logging
import multiprocessing
import os
import pprint
import re

# %%
import nltk
import gensim.models.word2vec as w2v
import sklearn.manifold
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Set up logging**

# %%
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# **Download NLTK tokenizer models (only the first time)**

# %%
nltk.download("punkt") # tokenizer
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to /home/dani/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/dani/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## Prepare Corpus

# %% [markdown]
# **Load books from files**

# %%
book_filenames = sorted(glob.glob("data/*.txt"))

# %%
print("Found books:")
book_filenames
# Out:
# Found books:
# ['data/got1.txt',
#  'data/got2.txt',
#  'data/got3.txt',
#  'data/got4.txt',
#  'data/got5.txt']

# %% [markdown]
# **Combine the books into one string**

# %%
corpus_raw = u""  ## usa unicode
for book_filename in book_filenames:
    print("Reading '{0}'...".format(book_filename))
    with codecs.open(book_filename, "r", "utf-8") as book_file:
        corpus_raw += book_file.read()
    print("Corpus is now {0} characters long".format(len(corpus_raw)))
    print()
# Out:
# Reading 'data/got1.txt'...
# Corpus is now 1770659 characters long
#
# Reading 'data/got2.txt'...
# Corpus is now 4071041 characters long
#
# Reading 'data/got3.txt'...
# Corpus is now 6391405 characters long
#
# Reading 'data/got4.txt'...
# Corpus is now 8107945 characters long
#
# Reading 'data/got5.txt'...
# Corpus is now 9719485 characters long

# %% [markdown]
# **Split the corpus into sentences**

# %%
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

# %%
raw_sentences = tokenizer.tokenize(corpus_raw)

# %%
#convert into a list of words
#rtemove unnnecessary,, split into words, no hyphens
#list of words
def sentence_to_wordlist(raw):
    clean = re.sub("[^a-zA-Z]"," ", raw)
    words = clean.split()
    return words

# %%
#sentence where each word is tokenized
sentences = []
for raw_sentence in raw_sentences:
    if len(raw_sentence) > 0:
        sentences.append(sentence_to_wordlist(raw_sentence))

# %%
print(raw_sentences[5])  # in the 5th index
print(sentence_to_wordlist(raw_sentences[5]))
# Out:
# He was an old man, past fifty, and he had seen the lordlings come and go.
# [u'He', u'was', u'an', u'old', u'man', u'past', u'fifty', u'and', u'he', u'had', u'seen', u'the', u'lordlings', u'come', u'and', u'go']

# %%
token_count = sum([len(sentence) for sentence in sentences])
print("The book corpus contains {0:,} tokens".format(token_count))
# Out:
# The book corpus contains 1,818,103 tokens

# %% [markdown]
# ## Train Word2Vec

# %%
#ONCE we have vectors
#step 3 - build model
#3 main tasks that vectors help with
#DISTANCE, SIMILARITY, RANKING

# Dimensionality of the resulting word vectors.
#more dimensions, more computationally expensive to train
#but also more accurate
#more dimensions = more generalized
num_features = 300

# Minimum word count threshold.
min_word_count = 3

# Number of threads to run in parallel.
#more workers, faster we train
num_workers = multiprocessing.cpu_count()

# Context window length.
context_size = 7

# Downsample setting for frequent words.
#0 - 1e-5 is good for this
downsampling = 1e-3

# Seed for the RNG, to make the results reproducible.
#random number generator
#deterministic, good for debugging
seed = 1

# %%
num_workers
# Out:
# 4

# %%
thrones2vec = w2v.Word2Vec(
    sg=1,
    seed=seed,
    workers=num_workers,
    size=num_features,
    min_count=min_word_count,
    window=context_size,
    sample=downsampling
)

# %%
thrones2vec.build_vocab(sentences)
# Out:
# 2020-12-17 11:52:36,832 : INFO : collecting all words and their counts
# 2020-12-17 11:52:36,833 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-12-17 11:52:36,907 : INFO : PROGRESS: at sentence #10000, processed 140984 words, keeping 10280 word types
# 2020-12-17 11:52:36,979 : INFO : PROGRESS: at sentence #20000, processed 279730 words, keeping 13558 word types
# 2020-12-17 11:52:37,053 : INFO : PROGRESS: at sentence #30000, processed 420336 words, keeping 16598 word types
# 2020-12-17 11:52:37,129 : INFO : PROGRESS: at sentence #40000, processed 556581 words, keeping 18324 word types
# 2020-12-17 11:52:37,200 : INFO : PROGRESS: at sentence #50000, processed 686247 words, keeping 19714 word types
# 2020-12-17 11:52:37,278 : INFO : PROGRESS: at sentence #60000, processed 828497 words, keeping 21672 word types
# 2020-12-17 11:52:37,339 : INFO : PROGRESS: at sentence #70000, processed 973830 words, keeping 23093 word types
# 2020-12-17 11:52:37,400 : INFO : PROGRESS: at sentence #80000, processed 1114967 words, keeping 24252 word types
# 2020-12-17 11:52:37,454 : INFO : PROGRESS: at sentence #90000, processed 1260481 words, keeping 26007 word types
# 2020-12-17 11:52:37,519 : INFO : PROGRESS: at sentence #100000, processed 1393203 words, keeping 26884 word types
# 2020-12-17 11:52:37,585 : INFO : PROGRESS: at sentence #110000, processed 1532150 words, keeping 27809 word types
# 2020-12-17 11:52:37,632 : INFO : PROGRESS: at sentence #120000, processed 1680961 words, keeping 28486 word types
# 2020-12-17 11:52:37,682 : INFO : collected 29026 word types from a corpus of 1818103 raw words and 128868 sentences
# 2020-12-17 11:52:37,683 : INFO : Loading a fresh vocabulary
# 2020-12-17 11:52:37,777 : INFO : effective_min_count=3 retains 17277 unique words (59% of original 29026, drops 11749)
# 2020-12-17 11:52:37,778 : INFO : effective_min_count=3 leaves 1802699 word corpus (99% of original 1818103, drops 15404)
# 2020-12-17 11:52:37,902 : INFO : deleting the raw counts dictionary of 29026 items
# 2020-12-17 11:52:37,904 : INFO : sample=0.001 downsamples 50 most-common words
# 2020-12-17 11:52:37,905 : INFO : downsampling leaves estimated 1404424 word corpus (77.9% of prior 1802699)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-22-709c8b2b7fb2> in <module>
# ----> 1 thrones2vec.build_vocab(sentences)
#
# ~/anaconda3/envs/deep/lib/python3.8/site-packages/gensim/models/base_any2vec.py in build_vocab(self, sentences, corpus_file, update, progress_per, keep_raw_vocab, trim_rule, **kwargs)
#     923         self.corpus_count = corpus_count
#     924         self.corpus_total_words = total_words
# --> 925         report_values = self.vocabulary.prepare_vocab(
#     926             self.hs, self.negative, self.wv, update=update, keep_raw_vocab=keep_raw_vocab,
#     927             trim_rule=trim_rule, **kwargs)
#
# ~/anaconda3/envs/deep/lib/python3.8/site-packages/gensim/models/word2vec.py in prepare_vocab(self, hs, negative, wv, update, keep_raw_vocab, trim_rule, min_count, sample, dry_run)
#    1566
#    1567         if self.sorted_vocab and not update:
# -> 1568             self.sort_vocab(wv)
#    1569         if hs:
#    1570             # add info about each word's Huffman encoding
#
# ~/anaconda3/envs/deep/lib/python3.8/site-packages/gensim/models/word2vec.py in sort_vocab(self, wv)
#    1413         """Sort the vocabulary so the most frequent words have the lowest indexes."""
#    1414         if len(wv.vectors):
# -> 1415             raise RuntimeError("cannot sort vocabulary after model weights already initialized.")
#    1416         wv.index2word.sort(key=lambda word: wv.vocab[word].count, reverse=True)
#    1417         for i, word in enumerate(wv.index2word):
#
# RuntimeError: cannot sort vocabulary after model weights already initialized.

# %%
print("Word2Vec vocabulary length:", len(thrones2vec.wv.vocab))
# Out:
# Word2Vec vocabulary length: 17277

# %% [markdown]
# **Start training, this might take a minute or two...**

# %%
thrones2vec.train(sentences, epochs=3, total_examples=thrones2vec.corpus_count)
# Out:
# 2020-12-17 12:01:08,419 : INFO : training model with 4 workers on 17277 vocabulary and 300 features, using sg=1 hs=0 sample=0.001 negative=5 window=7
# 2020-12-17 12:01:09,436 : INFO : EPOCH 1 - PROGRESS: at 6.03% examples, 84692 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:10,607 : INFO : EPOCH 1 - PROGRESS: at 16.05% examples, 102943 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:11,650 : INFO : EPOCH 1 - PROGRESS: at 26.54% examples, 115178 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:12,661 : INFO : EPOCH 1 - PROGRESS: at 36.52% examples, 118708 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:13,699 : INFO : EPOCH 1 - PROGRESS: at 46.02% examples, 120240 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:14,739 : INFO : EPOCH 1 - PROGRESS: at 55.68% examples, 122430 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:15,772 : INFO : EPOCH 1 - PROGRESS: at 65.00% examples, 123155 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:16,777 : INFO : EPOCH 1 - PROGRESS: at 74.53% examples, 123965 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:17,809 : INFO : EPOCH 1 - PROGRESS: at 84.10% examples, 124274 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:18,840 : INFO : EPOCH 1 - PROGRESS: at 92.94% examples, 124491 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:19,478 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-17 12:01:19,553 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-17 12:01:19,577 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-17 12:01:19,662 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-17 12:01:19,663 : INFO : EPOCH - 1 : training on 1818103 raw words (1404120 effective words) took 11.2s, 125028 effective words/s
# 2020-12-17 12:01:20,682 : INFO : EPOCH 2 - PROGRESS: at 7.67% examples, 107819 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:21,816 : INFO : EPOCH 2 - PROGRESS: at 18.24% examples, 118992 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:22,854 : INFO : EPOCH 2 - PROGRESS: at 27.71% examples, 121559 words/s, in_qsize 5, out_qsize 2
# 2020-12-17 12:01:23,954 : INFO : EPOCH 2 - PROGRESS: at 37.19% examples, 119276 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:25,025 : INFO : EPOCH 2 - PROGRESS: at 46.57% examples, 119927 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:26,109 : INFO : EPOCH 2 - PROGRESS: at 54.59% examples, 117735 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:27,214 : INFO : EPOCH 2 - PROGRESS: at 61.16% examples, 112826 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:28,281 : INFO : EPOCH 2 - PROGRESS: at 66.57% examples, 107796 words/s, in_qsize 6, out_qsize 1
# 2020-12-17 12:01:29,390 : INFO : EPOCH 2 - PROGRESS: at 73.98% examples, 105783 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:30,417 : INFO : EPOCH 2 - PROGRESS: at 80.84% examples, 104286 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:31,440 : INFO : EPOCH 2 - PROGRESS: at 86.86% examples, 102409 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:32,468 : INFO : EPOCH 2 - PROGRESS: at 92.91% examples, 101383 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:33,308 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-17 12:01:33,481 : INFO : EPOCH 2 - PROGRESS: at 99.05% examples, 100691 words/s, in_qsize 2, out_qsize 1
# 2020-12-17 12:01:33,485 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-17 12:01:33,526 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-17 12:01:33,570 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-17 12:01:33,572 : INFO : EPOCH - 2 : training on 1818103 raw words (1405060 effective words) took 13.9s, 101132 effective words/s
# 2020-12-17 12:01:34,608 : INFO : EPOCH 3 - PROGRESS: at 4.32% examples, 60401 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:35,645 : INFO : EPOCH 3 - PROGRESS: at 10.41% examples, 71291 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:36,664 : INFO : EPOCH 3 - PROGRESS: at 15.52% examples, 70145 words/s, in_qsize 6, out_qsize 1
# 2020-12-17 12:01:37,712 : INFO : EPOCH 3 - PROGRESS: at 22.07% examples, 74703 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:38,719 : INFO : EPOCH 3 - PROGRESS: at 29.49% examples, 79656 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:39,752 : INFO : EPOCH 3 - PROGRESS: at 36.52% examples, 81390 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:40,787 : INFO : EPOCH 3 - PROGRESS: at 43.42% examples, 82530 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:41,876 : INFO : EPOCH 3 - PROGRESS: at 50.38% examples, 83838 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:42,977 : INFO : EPOCH 3 - PROGRESS: at 57.28% examples, 84708 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:44,114 : INFO : EPOCH 3 - PROGRESS: at 65.00% examples, 85879 words/s, in_qsize 8, out_qsize 0
# 2020-12-17 12:01:45,178 : INFO : EPOCH 3 - PROGRESS: at 72.12% examples, 86592 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:46,191 : INFO : EPOCH 3 - PROGRESS: at 79.12% examples, 86988 words/s, in_qsize 6, out_qsize 1
# 2020-12-17 12:01:47,239 : INFO : EPOCH 3 - PROGRESS: at 85.67% examples, 87055 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:48,262 : INFO : EPOCH 3 - PROGRESS: at 91.43% examples, 86741 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:49,276 : INFO : EPOCH 3 - PROGRESS: at 96.47% examples, 86046 words/s, in_qsize 7, out_qsize 0
# 2020-12-17 12:01:49,673 : INFO : worker thread finished; awaiting finish of 3 more threads
# 2020-12-17 12:01:49,732 : INFO : worker thread finished; awaiting finish of 2 more threads
# 2020-12-17 12:01:49,789 : INFO : worker thread finished; awaiting finish of 1 more threads
# 2020-12-17 12:01:49,832 : INFO : worker thread finished; awaiting finish of 0 more threads
# 2020-12-17 12:01:49,834 : INFO : EPOCH - 3 : training on 1818103 raw words (1404503 effective words) took 16.2s, 86453 effective words/s
# 2020-12-17 12:01:49,836 : INFO : training on a 5454309 raw words (4213683 effective words) took 41.4s, 101744 effective words/s
# (4213683, 5454309)

# %% [markdown]
# **Save to file, can be useful later**

# %%
if not os.path.exists("trained"):
    os.makedirs("trained")

# %%
thrones2vec.save(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2020-12-17 12:02:27,763 : INFO : saving Word2Vec object under trained/thrones2vec.w2v, separately None
# 2020-12-17 12:02:27,765 : INFO : not storing attribute vectors_norm
# 2020-12-17 12:02:27,774 : INFO : not storing attribute cum_table
# 2020-12-17 12:02:28,529 : INFO : saved trained/thrones2vec.w2v

# %% [markdown]
# ## Explore the trained model.

# %%
thrones2vec = w2v.Word2Vec.load(os.path.join("trained", "thrones2vec.w2v"))
# Out:
# 2020-12-17 12:03:12,671 : INFO : loading Word2Vec object from trained/thrones2vec.w2v
# 2020-12-17 12:03:13,188 : INFO : loading wv recursively from trained/thrones2vec.w2v.wv.* with mmap=None
# 2020-12-17 12:03:13,190 : INFO : setting ignored attribute vectors_norm to None
# 2020-12-17 12:03:13,191 : INFO : loading vocabulary recursively from trained/thrones2vec.w2v.vocabulary.* with mmap=None
# 2020-12-17 12:03:13,193 : INFO : loading trainables recursively from trained/thrones2vec.w2v.trainables.* with mmap=None
# 2020-12-17 12:03:13,194 : INFO : setting ignored attribute cum_table to None
# 2020-12-17 12:03:13,196 : INFO : loaded trained/thrones2vec.w2v

# %% [markdown]
# ### Compress the word vectors into 2D space and plot them

# %%
#my video - how to visualize a dataset easily
tsne = sklearn.manifold.TSNE(n_components=2, random_state=0)

# %%
all_word_vectors_matrix = thrones2vec.wv.syn0
# Out:
# <ipython-input-36-d3183187c341>:1: DeprecationWarning: Call to deprecated `syn0` (Attribute will be removed in 4.0.0, use self.vectors instead).
#   all_word_vectors_matrix = thrones2vec.wv.syn0

# %% [markdown]
# **Train t-SNE, this could take a minute or two...**

# %%
all_word_vectors_matrix_2d = tsne.fit_transform(all_word_vectors_matrix)

# %% [markdown]
# **Plot the big picture**

# %%
points = pd.DataFrame(
    [
        (word, coords[0], coords[1])
        for word, coords in [
            (word, all_word_vectors_matrix_2d[thrones2vec.wv.vocab[word].index])
            for word in thrones2vec.wv.vocab
        ]
    ],
    columns=["word", "x", "y"]
)

# %%
points.head(5)
# Out:
#        word          x          y
# 0      This -54.830406  36.673500
# 1   edition  -8.635741 -71.344269
# 2       the  -1.172902  33.095230
# 3  complete -15.005488  -1.841101
# 4        of   8.043488  21.129494

# %%
sns.set_context("poster")

# %%
points.plot.scatter("x", "y", s=10, figsize=(20, 12))
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# **Zoom in to some interesting places**

# %%
def plot_region(x_bounds, y_bounds):
    slice = points[
        (x_bounds[0] <= points.x) & (x_bounds[1] <= points.x) & 
        (y_bounds[0] <= points.y) & (y_bounds[1] <= points.y)]
    
    ax = slice.plot.scatter("x", "y", s=23, figsize=(10, 8))
    
    for i, point in slice.iterrows():
        ax.text(point.x + 0.005, point.y + 0.005, point.word, fontsize=10)

# %% [markdown]
# **People related to Kingsguard ended up together**

# %%
plot_region(x_bounds=(-32, 30), y_bounds=(35, 32))

# %% [markdown]
# **Food products are grouped nicely as well. Aerys (The Mad King) being close to "roasted" also looks sadly correct**

# %%
plot_region(x_bounds=(0, 1), y_bounds=(4.3, 4.5))

# %% [markdown]
# ### Explore semantic similarities between book characters

# %% [markdown]
# **Words closest to the given word**

# %%
thrones2vec.wv.most_similar("Dany")
# Out:
# [('Brienne', 0.7949414849281311),
#  ('Irri', 0.791239857673645),
#  ('she', 0.7814699411392212),
#  ('Hotah', 0.7776210308074951),
#  ('Cersei', 0.7506589889526367),
#  ('Daario', 0.7465813159942627),
#  ('Missandei', 0.7423592805862427),
#  ('Arianne', 0.739308774471283),
#  ('Jorah', 0.7390402555465698),
#  ('Catelyn', 0.7337198257446289)]

# %%
thrones2vec.wv.most_similar("Aerys")
# Out:
# [('Rhaegar', 0.9357785582542419),
#  ('Mad', 0.9322184324264526),
#  ('Daeron', 0.9313942790031433),
#  ('Jaehaerys', 0.9195157885551453),
#  ('Elia', 0.9021778106689453),
#  ('Brandon', 0.8881731033325195),
#  ('Myrcella', 0.8873920440673828),
#  ('Aegon', 0.8867558836936951),
#  ('Hoster', 0.8862061500549316),
#  ('Viserys', 0.8852996230125427)]

# %%
thrones2vec.wv.most_similar("direwolf")
# Out:
# [('giant', 0.8060779571533203),
#  ('wight', 0.7998877763748169),
#  ('stableboy', 0.798065721988678),
#  ('infant', 0.7972656488418579),
#  ('Greyjoy', 0.7953022718429565),
#  ('quivering', 0.7935515642166138),
#  ('statue', 0.7925091981887817),
#  ('horror', 0.7907163500785828),
#  ('peak', 0.7898985743522644),
#  ('ghost', 0.7898136377334595)]

# %% [markdown]
# **Linear relationships between word pairs**

# %%
def nearest_similarity_cosmul(start1, end1, end2):
    similarities = thrones2vec.wv.most_similar_cosmul(
        positive=[end2, start1],
        negative=[end1]
    )
    start2 = similarities[0][0]
    print("{start1} is related to {end1}, as {start2} is related to {end2}".format(**locals()))
    return start2

# %%
nearest_similarity_cosmul("Stark", "Winterfell", "Riverrun")
nearest_similarity_cosmul("Jaime", "sword", "wine")
nearest_similarity_cosmul("Arya", "Nymeria", "dragons")
# Out:
# Stark is related to Winterfell, as Tully is related to Riverrun
# Jaime is related to sword, as drank is related to wine
# Arya is related to Nymeria, as dreams is related to dragons
# 'dreams'
